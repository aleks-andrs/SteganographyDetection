# %%
import cv2
import pystegano
import os
import requests
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Documentation
help(pystegano.lsb_grayscale)
# Out:
# Help on class lsb_grayscale in module pystegano.pystegano:
#
# class lsb_grayscale(builtins.object)
#  |  Steganographic tools based on least significant bit (lsb).
#  |  Thesse methods receive an RGB image and outputs a grayscale image.
#  |
#  |  Methods defined here:
#  |
#  |  decode(cover_image)
#  |      Retrives a secret_message (string) from an image (image) using lsb steganography.
#  |      This method receive an RGB image and outputs a grayscale image.
#  |
#  |  encode(cover_image, secret_message)
#  |      Stores a secret_message (string) into a cover_image (image) using lsb steganography.
#  |      This method receive an RGB image and outputs a grayscale image.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# Generate Lorem Ipsum text
def random_message():
    response = requests.get("http://loripsum.net/api/5/headers/plaintext")
    if response.status_code == 200:
        secret_msg = response.text
    else:
        # Default secret message, when requests fail
        secret_msg = "Hello There!"
    return secret_msg

# %%
# Set directory of cover images
cover_dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# Set working directory
dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset LSB Greyscale"

# %%
# Add stego payload
for i, filename in enumerate(os.listdir(cover_dirname)):
    cover_image = cv2.imread(cover_dirname + "/" + filename, cv2.IMREAD_UNCHANGED)
    secret_message = random_message()
    encoded_image = pystegano.lsb_grayscale.encode(cover_image, secret_message)
    cv2.imwrite(dirname + "/LSBG" + filename, encoded_image)

# %%
# Display the stego image
test_image = cv2.imread(dirname + "/LSBG9.png")
plt.imshow(test_image)
plt.show()

# %%
# Load stego image
stego_image = cv2.imread(dirname + "/LSBG10.png", cv2.IMREAD_UNCHANGED)

# %%
decoded_message = pystegano.lsb_grayscale.decode(stego_image)

# %%
print(decoded_message)
# Out:
# In schola desinis.
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Quod cum ille dixisset et satis disputatum videretur, in oppidum ad Pomponium perreximus omnes. Illud mihi a te nimium festinanter dictum videtur, sapientis omnis esse semper beatos; Istic sum, inquit. Nihil opus est exemplis hoc facere longius. Videsne ut, quibus summa est in voluptate, perspicuum sit quid iis faciendum sit aut non faciendum? Hanc quoque iucunditatem, si vis, transfer in animum; Duo Reges: constructio interrete. Tanti autem aderant vesicae et torminum morbi, ut nihil ad eorum magnitudinem posset accedere.
#
# Quaero igitur, quo modo hae tantae commendationes a natura profectae subito a sapientia relictae sint. Fatebuntur Stoici haec omnia dicta esse praeclare, neque eam causam Zenoni desciscendi fuisse. Nam et complectitur verbis, quod vult, et dicit plane, quod intellegam;
#
# Quod ea non occurrentia fingunt, vincunt Aristonem; Recte, inquit, intellegis. Expectoque quid ad id, quod quaerebam, respondeas. Causa autem fuit huc veniendi ut quosdam hinc libros promerem. Quamquam tu hanc copiosiorem etiam soles dicere.
#
# Sed quia studebat laudi et dignitati, multum in virtute processerat.
#
# Quis non odit sordidos, vanos, leves, futtiles? Modo etiam paulum ad dexteram de via declinavi, ut ad Pericli sepulcrum accederem. Hoc dixerit potius Ennius: Nimium boni est, cui nihil est mali.
#
# Te ipsum, dignissimum maioribus tuis, voluptasne induxit, ut adolescentulus eriperes P.
#
# Nemo nostrum istius generis asotos iucunde putat vivere. Tu vero, inquam, ducas licet, si sequetur; Vitiosum est enim in dividendo partem in genere numerare. Nos commodius agimus. Non pugnem cum homine, cur tantum habeat in natura boni; Perturbationes autem nulla naturae vi commoventur, omniaque ea sunt opiniones ac iudicia levitatis. Quem Tiberina descensio festo illo die tanto gaudio affecit, quanto L. Videamus animi partes, quarum est conspectus illustrior;
