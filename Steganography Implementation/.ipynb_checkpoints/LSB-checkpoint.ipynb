# %%
import cv2
import pystegano
import os
from IPython.display import Image, display
import requests

# %%
# Documentation
help(pystegano.lsb)
# Out:
# Help on class lsb in module pystegano.pystegano:
#
# class lsb(builtins.object)
#  |  Steganographic tools based on least significant bit (lsb).
#  |
#  |  Methods defined here:
#  |
#  |  decode(image)
#  |      Retrives a secret_message (string) from an image (image) using lsb steganography.
#  |
#  |  encode(cover_image, secret_message)
#  |      Stores a secret_message (string) into a cover_image (image) using lsb steganography.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# Generate Lorem Ipsum text
response = requests.get("http://loripsum.net/api/10/headers/plaintext")
if response.status_code == 200:
    secret_message = response.text
else:
    # Default secret message
    secret_message = "HelloThere!"

# %%
print(secret_message)
# Out:
# Aliter autem vobis placet.
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Erat enim Polemonis. Quo modo autem philosophus loquitur? Itaque contra est, ac dicitis; Quid loquor de nobis, qui ad laudem et ad decus nati, suscepti, instituti sumus? Quo modo autem philosophus loquitur? Quod autem magnum dolorem brevem, longinquum levem esse dicitis, id non intellego quale sit. Duo Reges: constructio interrete. Tu vero, inquam, ducas licet, si sequetur;
#
# Sed residamus, inquit, si placet.
#
# Qui ita affectus, beatum esse numquam probabis; Ita fit cum gravior, tum etiam splendidior oratio. Non quaeritur autem quid naturae tuae consentaneum sit, sed quid disciplinae. Etiam beatissimum?
#
# Tum mihi Piso: Quid ergo?
#
# Esse enim, nisi eris, non potes. Ergo in utroque exercebantur, eaque disciplina effecit tantam illorum utroque in genere dicendi copiam. Ut enim consuetudo loquitur, id solum dicitur honestum, quod est populari fama gloriosum. Dolere malum est: in crucem qui agitur, beatus esse non potest. Atque haec coniunctio confusioque virtutum tamen a philosophis ratione quadam distinguitur. Illa argumenta propria videamus, cur omnia sint paria peccata. Hoc enim constituto in philosophia constituta sunt omnia. Etenim si delectamur, cum scribimus, quis est tam invidus, qui ab eo nos abducat? Collatio igitur ista te nihil iuvat.
#
# Ita similis erit ei finis boni, atque antea fuerat, neque idem tamen; Videamus igitur sententias eorum, tum ad verba redeamus. Quae qui non vident, nihil umquam magnum ac cognitione dignum amaverunt. Omnes enim iucundum motum, quo sensus hilaretur. Minime id quidem, inquam, alienum, multumque ad ea, quae quaerimus, explicatio tua ista profecerit. Quid turpius quam sapientis vitam ex insipientium sermone pendere?
#
# Sed id ne cogitari quidem potest quale sit, ut non repugnet ipsum sibi. Nobis aliter videtur, recte secusne, postea; Earum etiam rerum, quas terra gignit, educatio quaedam et perfectio est non dissimilis animantium. Quid enim ab antiquis ex eo genere, quod ad disserendum valet, praetermissum est? Habes, inquam, Cato, formam eorum, de quibus loquor, philosophorum. Paupertas si malum est, mendicus beatus esse nemo potest, quamvis sit sapiens.
#
# Ego vero volo in virtute vim esse quam maximam;
#
# Quod est, ut dixi, habere ea, quae secundum naturam sint, vel omnia vel plurima et maxima. Tum, Quintus et Pomponius cum idem se velle dixissent, Piso exorsus est. Ut necesse sit omnium rerum, quae natura vigeant, similem esse finem, non eundem. Quicquid enim a sapientia proficiscitur, id continuo debet expletum esse omnibus suis partibus; Eaedem res maneant alio modo. Nummus in Croesi divitiis obscuratur, pars est tamen divitiarum.
#
# Estne, quaeso, inquam, sitienti in bibendo voluptas? Quod cum dixissent, ille contra. Quod non faceret, si in voluptate summum bonum poneret. Illa argumenta propria videamus, cur omnia sint paria peccata. Quae diligentissime contra Aristonem dicuntur a Chryippo.
#
# Laboro autem non sine causa;
#
# Iis igitur est difficilius satis facere, qui se Latina scripta dicunt contemnere. Confecta res esset. Aut haec tibi, Torquate, sunt vituperanda aut patrocinium voluptatis repudiandum. An me, inquam, nisi te audire vellem, censes haec dicturum fuisse? An quod ita callida est, ut optime possit architectari voluptates?
#
# Sed nimis multa. Mene ergo et Triarium dignos existimas, apud quos turpiter loquare? At habetur! Et ego id scilicet nesciebam! Sed ut sit, etiamne post mortem coletur? Semovenda est igitur voluptas, non solum ut recta sequamini, sed etiam ut loqui deceat frugaliter. Quid, de quo nulla dissensio est? Illa argumenta propria videamus, cur omnia sint paria peccata. Quae contraria sunt his, malane?
#
# An tu me de L.
#
# Beatus autem esse in maximarum rerum timore nemo potest. Bestiarum vero nullum iudicium puto. Ipse Epicurus fortasse redderet, ut Sextus Peducaeus, Sex. Aliter enim explicari, quod quaeritur, non potest. Si qua in iis corrigere voluit, deteriora fecit. Num quid tale Democritus? An ea, quae per vinitorem antea consequebatur, per se ipsa curabit? Quae animi affectio suum cuique tribuens atque hanc, quam dico. Quae diligentissime contra Aristonem dicuntur a Chryippo.

# %%
# Set directory of cover images
cover_dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# Set working directory
dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset LSB"

# %%
# Add stego payload
for i, filename in enumerate(os.listdir(cover_dirname)):
    cover_image = cv2.imread(cover_dirname + "/" + filename)
    encoded_image = pystegano.lsb.encode(cover_image, secret_message)
    cv2.imwrite(dirname + "/" + filename, encoded_image)

# %%
stego_image = cv2.imread(dirname + "/0.jpg")

# %%
# Display the stego image
display(Image(dirname + "/0.jpg"))

# %%
decoded_message = pystegano.lsb.decode(stego_image)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pystegano\pystegano.py in decode(image)
#      79                                                 try:
# ---> 80                                                         decoded_tag = bitarray.bitarray(bit_message).tobytes().decode('utf-8')
#      81                                                         bit_length = int(decoded_tag)+80
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x88 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-64466e2cd2be> in <module>
# ----> 1 decoded_message = pystegano.lsb.decode(stego_image)
#
# ~\anaconda3\lib\site-packages\pystegano\pystegano.py in decode(image)
#      82                                                         bit_message = ""
#      83                                                 except:
# ---> 84                                                         raise Exception("Can't decode secret on this image!")
#      85                                         elif bit_count >= bit_length:
#      86                                                 return bitarray.bitarray(bit_message).tobytes().decode('utf-8')
#
# Exception: Can't decode secret on this image!

# %%
stego_image.shape
# Out:
# (500, 800, 3)

# %%
print(decoded_message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-20d5c1a92fdd> in <module>
# ----> 1 print(decoded_message)
#
# NameError: name 'decoded_message' is not defined
