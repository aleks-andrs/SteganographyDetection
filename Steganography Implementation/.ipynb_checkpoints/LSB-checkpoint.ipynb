# %%
import cv2
import pystegano
import os
import requests
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Documentation
help(pystegano.lsb)
# Out:
# Help on class lsb in module pystegano.pystegano:
#
# class lsb(builtins.object)
#  |  Steganographic tools based on least significant bit (lsb).
#  |
#  |  Methods defined here:
#  |
#  |  decode(image)
#  |      Retrives a secret_message (string) from an image (image) using lsb steganography.
#  |
#  |  encode(cover_image, secret_message)
#  |      Stores a secret_message (string) into a cover_image (image) using lsb steganography.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# Generate Lorem Ipsum text
def random_message():
    response = requests.get("http://loripsum.net/api/10/headers/plaintext")
    if response.status_code == 200:
        secret_msg = response.text
    else:
        # Default secret message, when requests fail
        secret_msg = "Hello There!"
    return secret_msg

# %%
# Set directory of cover images
cover_dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# Set working directory
dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset LSB"

# %%
# Add stego payload
for i, filename in enumerate(os.listdir(cover_dirname)):
    cover_image = cv2.imread(cover_dirname + "/" + filename, cv2.IMREAD_UNCHANGED)
    secret_message = random_message()
    encoded_image = pystegano.lsb.encode(cover_image, secret_message)
    cv2.imwrite(dirname + "/LSB" + filename, encoded_image)

# %%
# Display the stego image
test_image = cv2.cvtColor(cv2.imread(dirname + "/LSB10.png"), cv2.COLOR_BGR2RGB)
plt.imshow(test_image)
plt.show()

# %%
# Load stego image
stego_image = cv2.imread(dirname + "/LSB10.png", cv2.IMREAD_UNCHANGED)

# %%
# Attempt to decode the secret message
decoded_message = pystegano.lsb.decode(stego_image)

# %%
print(decoded_message)
# Out:
# Sed ego in hoc resisto;
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Duo Reges: constructio interrete. Quo invento omnis ab eo quasi capite de summo bono et malo disputatio ducitur. Summum ením bonum exposuit vacuitatem doloris; Paria sunt igitur. An est aliquid, quod te sua sponte delectet? Princeps huius civitatis Phalereus Demetrius cum patria pulsus esset iniuria, ad Ptolomaeum se regem Alexandream contulit. Quodsi vultum tibi, si incessum fingeres, quo gravior viderere, non esses tui similis;
#
# Qui bonum omne in virtute ponit, is potest dicere perfici beatam vitam perfectione virtutis; Traditur, inquit, ab Epicuro ratio neglegendi doloris. Est autem officium, quod ita factum est, ut eius facti probabilis ratio reddi possit. Sin aliud quid voles, postea. An est aliquid, quod te sua sponte delectet? Perturbationes autem nulla naturae vi commoventur, omniaque ea sunt opiniones ac iudicia levitatis.
#
# Bonum incolumis acies: misera caecitas. Qui-vere falsone, quaerere mittimus-dicitur oculis se privasse; Color egregius, integra valitudo, summa gratia, vita denique conferta voluptatum omnium varietate. Verum hoc loco sumo verbis his eandem certe vim voluptatis Epicurum nosse quam ceteros. Vide, quaeso, rectumne sit. Apud ceteros autem philosophos, qui quaesivit aliquid, tacet; Quasi ego id curem, quid ille aiat aut neget. Non minor, inquit, voluptas percipitur ex vilissimis rebus quam ex pretiosissimis. Ubi ut eam caperet aut quando? Tecum optime, deinde etiam cum mediocri amico.
