# %%
import cv2
import pystegano
import os
import requests
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Documentation
help(pystegano.lsb)
# Out:
# Help on class lsb in module pystegano.pystegano:
#
# class lsb(builtins.object)
#  |  Steganographic tools based on least significant bit (lsb).
#  |
#  |  Methods defined here:
#  |
#  |  decode(image)
#  |      Retrives a secret_message (string) from an image (image) using lsb steganography.
#  |
#  |  encode(cover_image, secret_message)
#  |      Stores a secret_message (string) into a cover_image (image) using lsb steganography.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# Generate Lorem Ipsum text
def random_message():
    response = requests.get("http://loripsum.net/api/12/headers/plaintext")
    if response.status_code == 200:
        secret_msg = response.text
    else:
        # Default secret message, when requests fail
        secret_msg = "Hello There!"
    return secret_msg

# %%
# Set directory of cover images
cover_dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# Set working directory
dirname = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset LSB"

# %%
# Add stego payload
for i, filename in enumerate(os.listdir(cover_dirname)):
    cover_image = cv2.imread(cover_dirname + "/" + filename, cv2.IMREAD_UNCHANGED)
    secret_message = random_message()
    encoded_image = pystegano.lsb.encode(cover_image, secret_message)
    cv2.imwrite(dirname + "/LSB" + filename, encoded_image)

# %%
# Display the stego image
test_image = cv2.cvtColor(cv2.imread(dirname + "/LSB59.png"), cv2.COLOR_BGR2RGB)
plt.imshow(test_image)
plt.show()

# %%
# Load stego image
stego_image = cv2.imread(dirname + "/LSB59.png", cv2.IMREAD_UNCHANGED)

# %%
# Attempt to decode the secret message
decoded_message = pystegano.lsb.decode(stego_image)

# %%
print(decoded_message)
# Out:
# Quid ergo attinet gloriose loqui, nisi constanter loquare?
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Ad corpus diceres pertinere-, sed ea, quae dixi, ad corpusne refers? Est, ut dicis, inquam. Dolere malum est: in crucem qui agitur, beatus esse non potest. Quid est, quod ab ea absolvi et perfici debeat? Graecum enim hunc versum nostis omnes-: Suavis laborum est praeteritorum memoria. Videmus igitur ut conquiescere ne infantes quidem possint.
#
# Quo studio Aristophanem putamus aetatem in litteris duxisse? Praeclare enim Plato: Beatum, cui etiam in senectute contigerit, ut sapientiam verasque opiniones assequi possit. Roges enim Aristonem, bonane ei videantur haec: vacuitas doloris, divitiae, valitudo; Quicquid porro animo cernimus, id omne oritur a sensibus; Apparet statim, quae sint officia, quae actiones. Nummus in Croesi divitiis obscuratur, pars est tamen divitiarum. Tum ille timide vel potius verecunde: Facio, inquit. Sed eum qui audiebant, quoad poterant, defendebant sententiam suam.
#
# Inde sermone vario sex illa a Dipylo stadia confecimus. Qui autem voluptate vitam effici beatam putabit, qui sibi is conveniet, si negabit voluptatem crescere longinquitate? Qui-vere falsone, quaerere mittimus-dicitur oculis se privasse; Quis Pullum Numitorium Fregellanum, proditorem, quamquam rei publicae nostrae profuit, non odit?
#
