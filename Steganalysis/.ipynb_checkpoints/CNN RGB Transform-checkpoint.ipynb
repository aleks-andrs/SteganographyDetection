# %%
import os 
import cv2
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Cover image location
cover_dir = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# DCT RGB
dct_dir = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset DCT"

# %%
# Combine cover image data into a single array
cover_data = []
for i, filename in enumerate(os.listdir(cover_dir)):
    cover_image = cv2.imread(cover_dir + "/" + filename, cv2.IMREAD_UNCHANGED)
    cover_data.append(cover_image)
# The length of the array should be 60
print(len(cover_data))
# Out:
# 60

# %%
# Combine stego image data into a single array
stego_data = []
for i, filename in enumerate(os.listdir(dct_dir)):
    stego_image = cv2.imread(dct_dir + "/" + filename, cv2.IMREAD_UNCHANGED)
    stego_data.append(stego_image)
# The length of the array should be 60
print(len(stego_data))
# Out:
# 60

# %%
# Combine cover and stego images with corresponding labels 
labeled_data = []
for instance in cover_data:
    labeled_data.append([instance, 0])
for instance in stego_data:
    labeled_data.append([instance, 1])
len(labeled_data)
# Out:
# 120

# %%
type(labeled_data[1][0])
# Out:
# numpy.ndarray

# %%
plt.imshow(np.array(labeled_data[1][0]).reshape(120,120,3))
plt.title(labeled_data[0][1])
# Out:
# Text(0.5, 1.0, '0')

# %%
# Separate labels from data
X = []
Y = []
for img, label in labeled_data:
    X.append(img)
    Y.append(label)

# %%
print(len(X))
print(len(Y))
# Out:
# 120
# 120

# %%
sns.set_style('darkgrid')
sns.countplot(x = Y)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=12)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
# Normalise data
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
sns.countplot(x = y_train)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(120, 120, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 118, 118, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 59, 59, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 21632)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21633
# =================================================================
# Total params: 114,881
# Trainable params: 114,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 2s 495ms/step - loss: 0.6747 - accuracy: 0.4524
# Epoch 2/15
# 3/3 [==============================] - 2s 475ms/step - loss: 0.5761 - accuracy: 0.7262
# Epoch 3/15
# 3/3 [==============================] - 2s 475ms/step - loss: 0.4164 - accuracy: 0.7738
# Epoch 4/15
# 3/3 [==============================] - 2s 484ms/step - loss: 0.3973 - accuracy: 0.8571
# Epoch 5/15
# 3/3 [==============================] - 2s 483ms/step - loss: 0.2443 - accuracy: 0.8929
# Epoch 6/15
# 3/3 [==============================] - 2s 490ms/step - loss: 0.2177 - accuracy: 0.8810
# Epoch 7/15
# 3/3 [==============================] - 2s 485ms/step - loss: 0.2051 - accuracy: 0.9524
# Epoch 8/15
# 3/3 [==============================] - 2s 583ms/step - loss: 0.1581 - accuracy: 0.9405
# Epoch 9/15
# 3/3 [==============================] - 2s 477ms/step - loss: 0.1757 - accuracy: 0.9405
# Epoch 10/15
# 3/3 [==============================] - 2s 580ms/step - loss: 0.1181 - accuracy: 0.9405
# Epoch 11/15
# 3/3 [==============================] - 2s 485ms/step - loss: 0.1205 - accuracy: 0.9524
# Epoch 12/15
# 3/3 [==============================] - 2s 474ms/step - loss: 0.0725 - accuracy: 0.9643
# Epoch 13/15
# 3/3 [==============================] - 2s 477ms/step - loss: 0.0807 - accuracy: 0.9405
# Epoch 14/15
# 3/3 [==============================] - 2s 470ms/step - loss: 0.0528 - accuracy: 0.9643
# Epoch 15/15
# 3/3 [==============================] - 2s 523ms/step - loss: 0.0643 - accuracy: 0.9762

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(history.history['loss'], label='train')
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 2/2 - 0s - loss: 0.0868 - accuracy: 0.9722
