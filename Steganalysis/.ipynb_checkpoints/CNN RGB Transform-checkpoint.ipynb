# %%
import os 
import cv2
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Cover image location
cover_dir = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# DCT RGB
dct_dir = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset DCT"

# %%
# Combine cover image data into a single array
cover_data = []
for i, filename in enumerate(os.listdir(cover_dir)):
    cover_image = cv2.imread(cover_dir + "/" + filename, cv2.IMREAD_UNCHANGED)
    cover_data.append(cover_image)
# The length of the array should be 60
print(len(cover_data))
# Out:
# 60

# %%
# Combine stego image data into a single array
stego_data = []
for i, filename in enumerate(os.listdir(dct_dir)):
    stego_image = cv2.imread(dct_dir + "/" + filename, cv2.IMREAD_UNCHANGED)
    stego_data.append(stego_image)
# The length of the array should be 60
print(len(stego_data))
# Out:
# 60

# %%
# Combine cover and stego images with corresponding labels 
labeled_data = []
for instance in cover_data:
    labeled_data.append([instance, 0])
for instance in stego_data:
    labeled_data.append([instance, 1])
len(labeled_data)
# Out:
# 120

# %%
type(labeled_data[1][0])
# Out:
# numpy.ndarray

# %%
plt.imshow(np.array(labeled_data[1][0]).reshape(120,120,3))
plt.title(labeled_data[0][1])
# Out:
# Text(0.5, 1.0, '0')

# %%
# Separate labels from data
X = []
Y = []
for img, label in labeled_data:
    X.append(img)
    Y.append(label)

# %%
print(len(X))
print(len(Y))
# Out:
# 120
# 120

# %%
# Training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
# Split training set to obtain validation set
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.25, random_state=2)

# %%
# Get dataset lengths
x_train_len = len(x_train)
y_train_len = len(y_train)
x_test_len = len(x_test)
y_test_len = len(y_test)
x_valid_len = len(x_valid)
y_valid_len = len(y_valid)

# %%
print("Training set length: " + str(x_train_len) + ", and label set is: " + str(y_train_len))
print("Testing set length: " + str(x_test_len)+ ", and label set is: " + str(y_test_len))
print("Validation set length: " + str(x_valid_len)+ ", and label set is: " + str(y_valid_len))
# Out:
# Training set length: 72, and label set is: 72
# Testing set length: 24, and label set is: 24
# Validation set length: 24, and label set is: 24

# %%
# Change data types
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
x_valid = np.array(x_valid)
y_valid = np.array(y_valid)

# %%
# Normalise data
x_train = x_train / 255.0
x_test = x_test / 255.0
x_valid = x_valid / 255.0

# %%
# Display class distribution in training set, where 0 is cover and 1 is stego
sns.countplot(x = y_train)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Display class distribution in testing set, where 0 is cover and 1 is stego
sns.countplot(x = y_test)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Display class distribution in validation set, where 0 is cover and 1 is stego
sns.countplot(x = y_valid)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Start timer
start = datetime.datetime.now()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(120, 120, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 118, 118, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 59, 59, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 57, 57, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 21632)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 21633
# =================================================================
# Total params: 114,881
# Trainable params: 114,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.003),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=15, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/15
# 3/3 [==============================] - 2s 543ms/step - loss: 1.8360 - accuracy: 0.5556 - val_loss: 0.7407 - val_accuracy: 0.5833
# Epoch 2/15
# 3/3 [==============================] - 1s 431ms/step - loss: 0.7429 - accuracy: 0.6528 - val_loss: 0.6404 - val_accuracy: 0.5000
# Epoch 3/15
# 3/3 [==============================] - 1s 441ms/step - loss: 0.6496 - accuracy: 0.6389 - val_loss: 0.6157 - val_accuracy: 0.8333
# Epoch 4/15
# 3/3 [==============================] - 1s 436ms/step - loss: 0.6281 - accuracy: 0.8194 - val_loss: 0.6429 - val_accuracy: 0.5417
# Epoch 5/15
# 3/3 [==============================] - 1s 430ms/step - loss: 0.6439 - accuracy: 0.6111 - val_loss: 0.3964 - val_accuracy: 0.8333
# Epoch 6/15
# 3/3 [==============================] - 1s 431ms/step - loss: 0.4399 - accuracy: 0.8056 - val_loss: 0.3097 - val_accuracy: 0.8750
# Epoch 7/15
# 3/3 [==============================] - 1s 444ms/step - loss: 0.3366 - accuracy: 0.8194 - val_loss: 0.2391 - val_accuracy: 0.9167
# Epoch 8/15
# 3/3 [==============================] - 1s 437ms/step - loss: 0.2116 - accuracy: 0.9306 - val_loss: 0.2364 - val_accuracy: 0.8750
# Epoch 9/15
# 3/3 [==============================] - 1s 429ms/step - loss: 0.1662 - accuracy: 0.9444 - val_loss: 0.2668 - val_accuracy: 0.9167
# Epoch 10/15
# 3/3 [==============================] - 1s 439ms/step - loss: 0.2192 - accuracy: 0.9306 - val_loss: 0.2940 - val_accuracy: 0.9167
# Epoch 11/15
# 3/3 [==============================] - 1s 431ms/step - loss: 0.2018 - accuracy: 0.9306 - val_loss: 0.1700 - val_accuracy: 0.9167
# Epoch 12/15
# 3/3 [==============================] - 1s 435ms/step - loss: 0.1625 - accuracy: 0.9306 - val_loss: 0.1656 - val_accuracy: 0.9167
# Epoch 13/15
# 3/3 [==============================] - 1s 431ms/step - loss: 0.1094 - accuracy: 0.9444 - val_loss: 0.1553 - val_accuracy: 0.9167
# Epoch 14/15
# 3/3 [==============================] - 1s 436ms/step - loss: 0.0849 - accuracy: 0.9583 - val_loss: 0.1296 - val_accuracy: 0.9167
# Epoch 15/15
# 3/3 [==============================] - 1s 434ms/step - loss: 0.0539 - accuracy: 0.9722 - val_loss: 0.1294 - val_accuracy: 0.8750

# %%
# End timer
end = datetime.datetime.now()

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %%
# Evaluate trained model accuracy on previously unseen data
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0473 - accuracy: 0.9583

# %%
# Evaluate model training time performance
duration=end-start
print ("Model training time: ", duration)
# Out:
# Model training time:  0:00:23.133063
