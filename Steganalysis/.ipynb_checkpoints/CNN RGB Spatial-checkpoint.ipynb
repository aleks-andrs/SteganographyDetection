# %%
import os 
import cv2
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import datasets, layers, models


import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Cover image location
cover_dir = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset Cover Images"
# LSB RGB
lsb_dir = "C:/Users/PC/Masters Files/SteganographyDetection/Datasets/Dataset LSB"

# %%
# Combine cover image data into a single array
cover_data = []
for i, filename in enumerate(os.listdir(cover_dir)):
    cover_image = cv2.imread(cover_dir + "/" + filename, cv2.IMREAD_UNCHANGED)
    cover_data.append(cover_image)
# The length of the array should be 60
print(len(cover_data))
# Out:
# 60

# %%
# Combine stego image data into a single array
stego_data = []
for i, filename in enumerate(os.listdir(lsb_dir)):
    stego_image = cv2.imread(lsb_dir + "/" + filename, cv2.IMREAD_UNCHANGED)
    stego_data.append(stego_image)
# The length of the array should be 60
print(len(stego_data))
# Out:
# 60

# %%
# Combine cover and stego images with corresponding labels 
labeled_data = []
for instance in cover_data:
    labeled_data.append([instance, 0])
for instance in stego_data:
    labeled_data.append([instance, 1])
len(labeled_data)
# Out:
# 120

# %%
type(labeled_data[1][0])
# Out:
# numpy.ndarray

# %%
plt.imshow(np.array(labeled_data[1][0]).reshape(120,120,3))
plt.title(labeled_data[0][1])
# Out:
# Text(0.5, 1.0, '0')

# %%
# Separate labels from data
X = []
Y = []
for img, label in labeled_data:
    X.append(img)
    Y.append(label)

# %%
print(len(X))
print(len(Y))
# Out:
# 120
# 120

# %%
sns.set_style('darkgrid')
sns.countplot(x = Y)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# Training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=12)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
# Normalise data
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
sns.countplot(x = y_train)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(120, 120, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 120, 120, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 60, 60, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 64)        2112
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 64)        4160
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                3686464
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 3,693,514
# Trainable params: 3,693,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer1 = keras.optimizers.Adam(learning_rate=0.03)
model.compile(optimizer=optimizer1,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 2s 397ms/step - loss: 21.2168 - accuracy: 0.4881
# Epoch 2/10
# 3/3 [==============================] - 1s 377ms/step - loss: 1.7126 - accuracy: 0.4405
# Epoch 3/10
# 3/3 [==============================] - 1s 270ms/step - loss: 0.8122 - accuracy: 0.4405
# Epoch 4/10
# 3/3 [==============================] - 1s 270ms/step - loss: 0.9090 - accuracy: 0.5357
# Epoch 5/10
# 3/3 [==============================] - 1s 269ms/step - loss: 1.7025 - accuracy: 0.4167
# Epoch 6/10
# 3/3 [==============================] - 1s 274ms/step - loss: 1.7906 - accuracy: 0.4881
# Epoch 7/10
# 3/3 [==============================] - 1s 264ms/step - loss: 0.8565 - accuracy: 0.5119
# Epoch 8/10
# 3/3 [==============================] - 1s 466ms/step - loss: 1.1118 - accuracy: 0.4881
# Epoch 9/10
# 3/3 [==============================] - 1s 279ms/step - loss: 1.7759 - accuracy: 0.4881
# Epoch 10/10
# 3/3 [==============================] - 1s 270ms/step - loss: 1.5105 - accuracy: 0.4881

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 2/2 - 0s - loss: 1.2748 - accuracy: 0.5278
